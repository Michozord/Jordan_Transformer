# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, ConfusionMatrixDisplay, confusion_matrix
from jordanutils import *
from nn_backend import SimpleNN, train_and_test_model
import pandas as pd
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed=21)

# %%
y_test, y_pred = train_and_test_model(
            "random", "random", eps=0.1, verbose=1, epochs=50, width=128, depth=5
        )

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Using device: privateuseone:0 (backend: directml)
# Epoch 01 - Loss: 1.2402 - Train Acc: 0.4910 - Val Acc: 0.4873
# Epoch 02 - Loss: 0.8914 - Train Acc: 0.5437 - Val Acc: 0.5336
# Epoch 03 - Loss: 0.9336 - Train Acc: 0.5678 - Val Acc: 0.5565
# Epoch 04 - Loss: 1.0521 - Train Acc: 0.5758 - Val Acc: 0.5641
# Epoch 05 - Loss: 0.9510 - Train Acc: 0.5733 - Val Acc: 0.5628
# Epoch 06 - Loss: 0.8305 - Train Acc: 0.5920 - Val Acc: 0.5797
# Epoch 07 - Loss: 0.8189 - Train Acc: 0.6052 - Val Acc: 0.5916
# Epoch 08 - Loss: 0.9171 - Train Acc: 0.6037 - Val Acc: 0.5890
# Epoch 09 - Loss: 0.6799 - Train Acc: 0.6111 - Val Acc: 0.5938
# Epoch 10 - Loss: 0.7972 - Train Acc: 0.6160 - Val Acc: 0.5981
# Epoch 11 - Loss: 0.7838 - Train Acc: 0.6122 - Val Acc: 0.5907
# Epoch 12 - Loss: 0.8692 - Train Acc: 0.6149 - Val Acc: 0.5940
# Epoch 13 - Loss: 0.7618 - Train Acc: 0.6190 - Val Acc: 0.5964
# Early stopping at epoch 13
