# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, ConfusionMatrixDisplay, confusion_matrix
from jordanutils import *
from nn_backend import SimpleNN, train_and_test_model
import pandas as pd
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed=21)

# %%
y_test, y_pred = train_and_test_model(
            "random", "random", eps=0.0, verbose=1, epochs=50, width=128, depth=5
        )

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Using device: privateuseone:0 (backend: directml)
# c:\Users\micha\Documents\Studia\Magisterka\venv\Lib\site-packages\torch\nn\modules\module.py:1553: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# c:\Users\micha\Documents\Studia\Magisterka\venv\Lib\site-packages\torch\optim\adam.py:534: UserWarning: The operator 'aten::lerp.Scalar_out' is not currently supported on the DML backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at C:\__w\1\s\pytorch-directml-plugin\torch_directml\csrc\dml\dml_cpu_fallback.cpp:17.)
#   torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
# Epoch 01 - Loss: 1.3720 - Train Acc: 0.5351 - Val Acc: 0.5348
# Epoch 02 - Loss: 1.3390 - Train Acc: 0.5611 - Val Acc: 0.5617
# Epoch 03 - Loss: 1.2697 - Train Acc: 0.5880 - Val Acc: 0.5853
# Epoch 04 - Loss: 1.3283 - Train Acc: 0.6103 - Val Acc: 0.6044
# Epoch 05 - Loss: 1.2249 - Train Acc: 0.6209 - Val Acc: 0.6131
# Epoch 06 - Loss: 1.3996 - Train Acc: 0.6379 - Val Acc: 0.6269
# Epoch 07 - Loss: 1.2066 - Train Acc: 0.6385 - Val Acc: 0.6275
# Epoch 08 - Loss: 1.2389 - Train Acc: 0.6410 - Val Acc: 0.6299
# Epoch 09 - Loss: 1.3141 - Train Acc: 0.6494 - Val Acc: 0.6365
# Epoch 10 - Loss: 1.1859 - Train Acc: 0.6605 - Val Acc: 0.6454
# Epoch 11 - Loss: 1.2679 - Train Acc: 0.6600 - Val Acc: 0.6468
# Epoch 12 - Loss: 1.2668 - Train Acc: 0.6602 - Val Acc: 0.6439
# Epoch 13 - Loss: 1.1251 - Train Acc: 0.6660 - Val Acc: 0.6522
# Epoch 14 - Loss: 1.2180 - Train Acc: 0.6606 - Val Acc: 0.6455
# Epoch 15 - Loss: 1.2730 - Train Acc: 0.5945 - Val Acc: 0.5732
# Epoch 16 - Loss: 1.2425 - Train Acc: 0.6627 - Val Acc: 0.6432
# Early stopping at epoch 16
